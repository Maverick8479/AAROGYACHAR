# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('disease_symptoms.csv')
df.head()
# Out:
#                Disease             Symptom_1   Symptom_2  \
# 0     Fungal infection               itching   skin_rash
# 1              Allergy   continuous_sneezing   shivering
# 2                 GERD          stomach_pain     acidity
# 3  Chronic cholestasis               itching    vomiting
# 4        Drug Reaction               itching   skin_rash
#
#                Symptom_3             Symptom_4             Symptom_5  \
# 0   nodal_skin_eruptions   dischromic _patches                   NaN
# 1                 chills    watering_from_eyes                   NaN
# 2       ulcers_on_tongue              vomiting                 cough
# 3         yellowish_skin                nausea      loss_of_appetite
# 4           stomach_pain   burning_micturition   spotting_ urination
#
#          Symptom_6           Symptom_7 Symptom_8 Symptom_9 Symptom_10  \
# 0              NaN                 NaN       NaN       NaN        NaN
# 1              NaN                 NaN       NaN       NaN        NaN
# 2       chest_pain                 NaN       NaN       NaN        NaN
# 3   abdominal_pain   yellowing_of_eyes       NaN       NaN        NaN
# 4              NaN                 NaN       NaN       NaN        NaN
#
#   Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15 Symptom_16 Symptom_17
# 0        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     40 non-null     object
#  1   Symptom_1   40 non-null     object
#  2   Symptom_2   40 non-null     object
#  3   Symptom_3   40 non-null     object
#  4   Symptom_4   40 non-null     object
#  5   Symptom_5   32 non-null     object
#  6   Symptom_6   26 non-null     object
#  7   Symptom_7   19 non-null     object
#  8   Symptom_8   16 non-null     object
#  9   Symptom_9   14 non-null     object
#  10  Symptom_10  12 non-null     object
#  11  Symptom_11  11 non-null     object
#  12  Symptom_12  7 non-null      object
#  13  Symptom_13  5 non-null      object
#  14  Symptom_14  2 non-null      object
#  15  Symptom_15  2 non-null      object
#  16  Symptom_16  2 non-null      object
#  17  Symptom_17  1 non-null      object
# dtypes: object(18)
# memory usage: 5.8+ KB

# %%
dm = pd.read_csv('disease_medicine.csv')
dr = pd.read_csv('disease_riskFactors.csv')
dm = dm.reset_index()
dr = dr.reset_index()
dm.head()
dr.drop[index]
# Out:
#    index  Medicine_ID       Medicine_Name  Disease_ID  \
# 0      0          201    Antifungal cream         101
# 1      1          202  Antifungal liquids         101
# 2      2          203   Antifungal sprays         101
# 3      3          204       Antihistamine         102
# 4      4          205             antacid         103
#
#                                 Medicine_Composition  \
# 0  clotrimazole, econazole, ketoconazole, miconaz...
# 1  clotrimazole, econazole, ketoconazole, miconaz...
# 2  clotrimazole, econazole, ketoconazole, miconaz...
# 3      Brompheniramine, Cetirizine, Chlorpheniramine
# 4  calcium carbonate, magnesium hydroxide, alumin...
#
#                                 Medicine_Description  Unnamed: 5  Unnamed: 6  \
# 0  a pharmaceutical fungicide or fungistatic used...         NaN         NaN
# 1  a pharmaceutical fungicide or fungistatic used...         NaN         NaN
# 2  a pharmaceutical fungicide or fungistatic used...         NaN         NaN
# 3  Antihistamines are drugs which treat allergic ...         NaN         NaN
# 4  An antacid is a substance which neutralizes st...         NaN         NaN
#
#    Unnamed: 7  Unnamed: 8
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
d = 'Common Cold'
for index, row in dr.iterrows():
    if row[2] == d:
        did = row[1]
        for i, r in dm.iterrows():
            if r[3] == did:
                print(r[2])
        print(did)
        break
# Out:
# Nasal decongestants
# Analgesic
# 122
